# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
from matplotlib.pyplot import figure


# set the chained_assignment option
pd.options.mode.chained_assignment = None

# creating data frame and reading data 
df = pd.read_csv(r'/Users/caaturday/Documents/Python/Movies Project/movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
#----------------- data cleaning 
'''checking to see if there is any missing data'''
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# replace Nans with zeros on the following columns
df['rating'] = df['rating'].replace(np.nan,0)
df['budget'] = df['budget'].replace(np.nan,0)
df['gross'] = df['gross'].replace(np.nan,0)

# will print false if nans were successfully removed 
check_for_nan = df['rating'].isnull().values.any()
print (check_for_nan)
check_for_nan = df['budget'].isnull().values.any()
print (check_for_nan)
check_for_nan = df['gross'].isnull().values.any()
print (check_for_nan)
# Out:
# False
# False
# False

# %%
# making floats into integers to get rid of decimals and make data look cleaner
df['budget'] = df['budget'].astype(int)
df['gross'] = df['gross'].astype(int)



str_released = df['released'].astype(str)

# %%
# str_released

#date = 'June 13, 1980'
table = pd.DataFrame(data=['June 13, 1980 (United States)'], index = [0])
import datetime
table.columns = ['date']

#table

table[['date', 'location']] = table.date.str.split(pat='(',expand=True)

# %%
df[['date', 'location']] = df.released.str.split(pat='(',expand=True)

# %%
#df['actual_year'] = pd.to_datetime(date).dt.year
df['actual_year'] = df['date'].astype(str).str[-5:]
df['actual_year']
# Out:
# 0       1980
# 1       1980
# 2       1980
# 3       1980
# 4       1980
#         ...
# 7663    2020
# 7664    2020
# 7665    2020
# 7666    2020
# 7667    2020
# Name: actual_year, Length: 7668, dtype: object

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'],  inplace = False, ascending = False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# setting plotting params
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
